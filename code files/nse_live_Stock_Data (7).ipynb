# %%
import pandas as pd

# Load with correct delimiter (comma)
df = pd.read_csv("EQUITY_L.csv", sep=",", skipinitialspace=True)

# Clean headers
df.columns = df.columns.str.strip()

# Filter only active equity stocks
df = df[df['SERIES'] == 'EQ']

# Clean SYMBOL column
df['SYMBOL'] = df['SYMBOL'].str.strip()

# Get symbol list
symbols = df['SYMBOL'].tolist()
print("Total symbols to fetch:", len(symbols))
# Out:
# Total symbols to fetch: 1822

# %%
import pandas as pd
from nsepython import nse_eq
import time
from datetime import datetime
import os

# ========== Step 1: Load Symbol Master ==========
def load_symbols(csv_path):
    df = pd.read_csv(csv_path, sep=",", skipinitialspace=True)
    df.columns = df.columns.str.strip().str.replace('\ufeff', '', regex=True)
    df = df[df['SERIES'] == 'EQ']  # Keep only EQ
    df['SYMBOL'] = df['SYMBOL'].str.strip()
    return df['SYMBOL'].tolist()

# ========== Step 2: Fetch Price for One Symbol ==========
def get_nse_price(symbol, retries=3):
    for i in range(retries):
        try:
            data = nse_eq(symbol)
            return data['priceInfo']['lastPrice']
        except Exception as e:
            print(f"{symbol} attempt {i+1} failed: {e}")
            time.sleep(1)
    return None

# ========== Step 3: Process in Batches and Save ==========
def fetch_and_save(symbols, batch_size=100, output_dir="live_prices"):
    os.makedirs(output_dir, exist_ok=True)
    all_prices = []
    today = datetime.now().strftime("%Y-%m-%d")
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    for i in range(0, len(symbols), batch_size):
        batch = symbols[i:i+batch_size]
        print(f"Processing batch {i} to {i+len(batch)}")

        for symbol in batch:
            price = get_nse_price(symbol)
            all_prices.append({'SYMBOL': symbol, 'PRICE': price, 'FETCHED_AT': timestamp})
            print(f"{symbol}: ₹{price}")
            time.sleep(1)

        # Save after each batch
        batch_df = pd.DataFrame(all_prices)
        batch_df.to_csv(f"{output_dir}/live_prices_{today}.csv", index=False)

        print("Batch saved.")
        time.sleep(10)  # Pause between batches

    print(f"All {len(all_prices)} prices saved to {output_dir}/live_prices_{today}.csv")

# %%
# ========== Step 4: Run ==========
if __name__ == "__main__":
    symbols = load_symbols("EQUITY_L.csv")
    fetch_and_save(symbols)
# Out:
# Processing batch 0 to 100
# 20MICRONS: ₹265.8
# 21STCENMGM: ₹60.25
# 360ONE: ₹1071
# 3IINFOLTD: ₹23.66
# 3MINDIA: ₹31315
# 3PLAND: ₹46.9
# 5PAISA: ₹385.6
# 63MOONS: ₹1043
# AAATECH: ₹87.56
# AADHARHFC: ₹498
# AAKASH: ₹9.9
# AARON: ₹457
# AARTECH: ₹68.3
# AARTIDRUGS: ₹534.7
# AARTIIND: ₹430.1
# AARTIPHARM: ₹944
# AARVI: ₹104.48
# AAVAS: ₹1838.7
# ABAN: ₹48.8
# ABB: ₹5647
# ABBOTINDIA: ₹33740
# ABCAPITAL: ₹260.1
# ABDL: ₹460.8
# ABFRL: ₹73.77
# ABMINTLLTD: ₹0
# ABREL: ₹2008.1
# ABSLAMC: ₹855
# ACC: ₹1849
# ACCELYA: ₹1402.5
# ACCURACY: ₹7.6
# ACE: ₹1105
# ACEINTEG: ₹24.67
# ACI: ₹666
# ACL: ₹70.53
# ACLGATI: ₹67
# ACMESOLAR: ₹271.8
# ACUTAAS: ₹1155
# ADANIENSOL: ₹813.8
# ADANIENT: ₹2549.5
# ADANIGREEN: ₹978
# ADANIPORTS: ₹1390
# ADANIPOWER: ₹571
# ADFFOODS: ₹267.9
# ADOR: ₹1042
# ADROITINFO: ₹10.81
# ADSL: ₹173
# ADVANIHOTR: ₹60.98
# ADVENZYMES: ₹327
# AEGISLOG: ₹734.85
# AEGISVOPAK: ₹254.41
# AEROFLEX: ₹205.28
# AETHER: ₹781
# AFCONS: ₹413.3
# AFFLE: ₹1800
# AFFORDABLE: ₹422
# AFIL: ₹7.16
# AFSL: ₹222.45
# AGARIND: ₹943
# AGARWALEYE: ₹456.1
# AGI: ₹940.45
# AGIIL: ₹1064
# AGRITECH: ₹143
# AGROPHOS: ₹40.6
# AHLADA: ₹64.99
# AHLEAST: ₹159.62
# AHLUCONT: ₹1018
# AIAENG: ₹3260
# AIIL: ₹2710
# AIRAN: ₹27.54
# AIROLAM: ₹111.32
# AJANTPHARM: ₹2791.5
# AJAXENGG: ₹673
# AJMERA: ₹934.7
# AJOONI: ₹5.68
# AKASH: ₹27.97
# AKG: ₹12.96
# AKSHARCHEM: ₹314.5
# AKUMS: ₹530
# AKZOINDIA: ₹3750.1
# ALANKIT: ₹15.77
# ALBERTDAVD: ₹888
# ALEMBICLTD: ₹115.43
# ALICON: ₹917.1
# ALIVUS: ₹1030.9
# ALKALI: ₹93.99
# ALKEM: ₹5000
# ALKYLAMINE: ₹2194.7
# ALLCARGO: ₹34.35
# ALLDIGI: ₹995
# ALMONDZ: ₹21.98
# ALOKINDS: ₹19.93
# ALPA: ₹102.02
# ALPHAGEO: ₹267.95
# AMBER: ₹7273.5
# AMBICAAGAR: ₹27.6
# AMBIKCO: ₹1575
# AMBUJACEM: ₹609.8
# AMDIND: ₹51.5
# AMJLAND: ₹60.5
# AMNPLST: ₹228
# Batch saved.
# Processing batch 100 to 200
# AMRUTANJAN: ₹673
# ANANDRATHI: ₹2586.1
# ANANTRAJ: ₹573.4
# ANDHRAPAP: ₹77.8
# ANDHRSUGAR: ₹80.03
# ANGELONE: ₹2719.8
# ANMOL: ₹16.39
# ANTGRAPHIC: ₹1.12
# ANUHPHR: ₹99.5
# ANUP: ₹2645
# ANURAS: ₹1152
# APARINDS: ₹8980
# APCL: ₹149.99
# APCOTEXIND: ₹395.95
# APEX: ₹248.37
# APLAPOLLO: ₹1550
# APLLTD: ₹999
# APOLLO: ₹170
# APOLLOHOSP: ₹7474
# APOLLOPIPE: ₹421.25
# APOLLOTYRE: ₹455.45
# APOLSINHOT: ₹1421.7
# APTUS: ₹348
# ARCHIDPLY: ₹100.03
# ARCHIES: ₹19.6
# ARE&M: ₹993.25
# ARENTERP: ₹48.5
# ARIES: ₹357.9
# ARIHANTCAP: ₹101.5
# ARIHANTSUP: ₹420.25
# ARKADE: ₹197.18
# ARMANFIN: ₹1650.3
# AROGRANITE: ₹37.36
# ARTEMISMED: ₹240
# ARTNIRMAN: ₹59
# ARVEE: ₹166
# ARVIND: ₹334.1
# ARVINDFASN: ₹500.2
# ARVSMART: ₹618.15
# ASAHIINDIA: ₹837
# ASAL: ₹551
# ASALCBR: ₹1090.1
# ASHAPURMIN: ₹548.9
# ASHIANA: ₹316
# ASHOKA: ₹201
# ASHOKAMET: ₹16.87
# ASHOKLEY: ₹122.1
# ASIANENE: ₹284.75
# ASIANPAINT: ₹2338.9
# ASIANTILES: ₹57.95
# ASKAUTOLTD: ₹511.9
# ASMS: ₹13.33
# ASPINWALL: ₹295.55
# ASTEC: ₹893.5
# ASTERDM: ₹581.5
# ASTRAL: ₹1440
# ASTRAMICRO: ₹975.2
# ASTRAZEN: ₹8844.5
# ATALREAL: ₹19.25
# ATAM: ₹101
# ATGL: ₹623.85
# ATHERENERG: ₹330.65
# ATL: ₹32.27
# ATLANTAA: ₹33.75
# ATUL: ₹6635.5
# ATULAUTO: ₹457.75
# AUBANK: ₹732.1
# AURIONPRO: ₹1400
# AUROPHARMA: ₹1120.2
# AURUM: ₹196.5
# AUSOMENT: ₹110
# AUTOAXLES: ₹1908
# AUTOIND: ₹75.24
# AVADHSUGAR: ₹465.4
# AVALON: ₹821.05
# AVANTEL: ₹136
# AVANTIFEED: ₹729
# AVG: ₹270
# AVL: ₹386.95
# AVROIND: ₹145
# AVTNPL: ₹76.32
# AWFIS: ₹606.8
# AWHCL: ₹605
# AWL: ₹269.4
# AXISBANK: ₹1086
# AXITA: ₹9
# AYMSYNTEX: ₹217.05
# AZAD: ₹1554.7
# BAIDFIN: ₹12.4
# BAJAJ-AUTO: ₹8074.5
# BAJAJCON: ₹234.5
# BAJAJELEC: ₹642.95
# BAJAJFINSV: ₹1985.4
# BAJAJHCARE: ₹516.25
# BAJAJHFL: ₹117.1
# BAJAJHIND: ₹25.01
# BAJAJHLDNG: ₹13811
# BAJAJINDEF: ₹410.6
# BAJEL: ₹239
# BAJFINANCE: ₹912.85
# Batch saved.
# Processing batch 200 to 300
# BALAJEE: ₹45.32
# BALAMINES: ₹1675
# BALAXI: ₹48.7
# BALKRISHNA: ₹21.36
# BALKRISIND: ₹2665.5
# BALMLAWRIE: ₹216.1
# BALPHARMA: ₹97.52
# BALRAMCHIN: ₹586
# BALUFORGE: ₹630
# BANARBEADS: ₹121.2
# BANARISUG: ₹3750
# BANCOINDIA: ₹611.15
# BANDHANBNK: ₹178.24
# BANG: ₹54.2
# BANKA: ₹91.78
# BANKBARODA: ₹243.3
# BANKINDIA: ₹113.04
# BANSALWIRE: ₹409.9
# BANSWRAS: ₹149
# BARBEQUE: ₹305.5
# BASF: ₹5030
# BASML: ₹31.38
# BATAINDIA: ₹1203.9
# BAYERCROP: ₹6300
# BBL: ₹2947.9
# BBOX: ₹498.9
# BBTC: ₹1943.4
# BBTCL: ₹196.9
# BCLIND: ₹44.75
# BCONCEPTS: ₹331.3
# BDL: ₹1660
# BEARDSELL: ₹31.89
# BECTORFOOD: ₹1520.1
# BEDMUTHA: ₹144.05
# BEL: ₹395.6
# BELRISE: ₹131
# BEML: ₹4148
# BEPL: ₹109.9
# BERGEPAINT: ₹559.6
# BFINVEST: ₹483.1
# BFUTILITIE: ₹763.05
# BHAGCHEM: ₹298
# BHAGERIA: ₹194
# BHAGYANGR: ₹97.5
# BHANDARI: ₹5.44
# BHARATFORG: ₹1200.2
# BHARATGEAR: ₹93
# BHARATRAS: ₹10595
# BHARATWIRE: ₹190
# BHARTIARTL: ₹1928
# BHARTIHEXA: ₹1790
# BHEL: ₹240.05
# BIGBLOC: ₹60.88
# BIKAJI: ₹773.3
# BIOCON: ₹394.15
# BIOFILCHEM: ₹46.25
# BIRLACABLE: ₹171.95
# BIRLACORPN: ₹1420.2
# BIRLAMONEY: ₹169.5
# BIRLANU: ₹2301.1
# BLACKBUCK: ₹462.55
# BLAL: ₹210.31
# BLBLIMITED: ₹14.41
# BLISSGVS: ₹154.45
# BLKASHYAP: ₹71.2
# BLS: ₹363
# BLSE: ₹188.7
# BLUEDART: ₹6725
# BLUEJET: ₹788
# BLUESTARCO: ₹1745
# BODALCHEM: ₹74.9
# BOMDYEING: ₹181.5
# BOROLTD: ₹332.3
# BORORENEW: ₹624
# BOROSCI: ₹170.7
# BOSCHLTD: ₹37800
# BPCL: ₹333.6
# BPL: ₹84.8
# BRIGADE: ₹1054.2
# BRITANNIA: ₹5599
# BSE: ₹2464
# BSHSL: ₹134.26
# BSOFT: ₹395.5
# BTML: ₹8.63
# BUTTERFLY: ₹740
# BVCL: ₹44
# CAMLINFINE: ₹267.1
# CAMPUS: ₹279.5
# CAMS: ₹4030
# CANBK: ₹110.65
# CANFINHOME: ₹773.2
# CANTABIL: ₹268.15
# CAPACITE: ₹318.55
# CAPITALSFB: ₹300.25
# CAPLIPOINT: ₹2037
# CARBORUNIV: ₹958.7
# CARERATING: ₹1743.7
# CARRARO: ₹482
# CARTRADE: ₹1879.8
# CARYSIL: ₹878.95
# Batch saved.
# Processing batch 300 to 400
# CASTROLIND: ₹222.6
# CCCL: ₹16.8
# CCHHL: ₹18.5
# CCL: ₹844
# CDSL: ₹1616
# CEATLTD: ₹3375
# CEIGALL: ₹261.65
# CELEBRITY: ₹12.97
# CELLO: ₹595.2
# CENTENKA: ₹512
# CENTEXT: ₹23.75
# CENTRALBK: ₹36.75
# CENTRUM: ₹37.2
# CENTUM: ₹2261.9
# CENTURYPLY: ₹740
# CERA: ₹6603
# CESC: ₹173.4
# CEWATER: ₹630
# CGCL: ₹182.32
# CGPOWER: ₹661.6
# CHALET: ₹917.25
# CHAMBLFERT: ₹538.1
# CHEMCON: ₹212
# CHEMFAB: ₹761.1
# CHEMPLASTS: ₹438
# CHENNPETRO: ₹692.05
# CHEVIOT: ₹1182
# CHOICEIN: ₹749.25
# CHOLAFIN: ₹1503.9
# CHOLAHLDNG: ₹1987
# CIEINDIA: ₹414
# CIFL: ₹37.05
# CIGNITITEC: ₹1587.2
# CINEVISTA: ₹18.7
# CIPLA: ₹1535
# CLEAN: ₹1238
# CLEDUCATE: ₹91.53
# CLSEL: ₹332
# CMSINFO: ₹490.95
# COALINDIA: ₹381.65
# COASTCORP: ₹36.1
# COCHINSHIP: ₹1806.4
# COFORGE: ₹1694.5
# COHANCE: ₹1016
# COLPAL: ₹2216
# COMPUSOFT: ₹21
# COMSYN: ₹132
# CONCOR: ₹598.05
# CONCORDBIO: ₹1883.9
# CONFIPET: ₹52.19
# CONSOFINVT: ₹201.65
# CONTROLPR: ₹727.2
# CORALFINAC: ₹48.1
# CORDSCABLE: ₹206
# COROMANDEL: ₹2436.8
# COSMOFIRST: ₹1072.5
# CPCAP: ₹168.37
# CRAFTSMAN: ₹6254
# CREATIVE: ₹655.5
# CREATIVEYE: ₹0
# CREDITACC: ₹1302
# CREST: ₹374.5
# CRISIL: ₹5520
# CROMPTON: ₹328.75
# CROWN: ₹158.9
# CSBBANK: ₹426.9
# CSLFINANCE: ₹311.65
# CUB: ₹207.39
# CUBEXTUB: ₹92.8
# CUMMINSIND: ₹3520
# CUPID: ₹148
# CYIENT: ₹1241
# CYIENTDLM: ₹460
# DABUR: ₹511.5
# DALBHARAT: ₹2230.1
# DALMIASUG: ₹377.95
# DAMCAPITAL: ₹237
# DAMODARIND: ₹37.9
# DATAMATICS: ₹880
# DATAPATTNS: ₹2676
# DAVANGERE: ₹3.47
# DBCORP: ₹276.05
# DBEIL: ₹139
# DBL: ₹462.25
# DBREALTY: ₹185.5
# DBSTOCKBRO: ₹28.85
# DCAL: ₹251
# DCBBANK: ₹137.79
# DCI: ₹253
# DCM: ₹111
# DCMNVL: ₹185
# DCMSHRIRAM: ₹1388.6
# DCMSRIND: ₹168.1
# DCW: ₹78.7
# DCXINDIA: ₹266
# DDEVPLSTIK: ₹310
# DECCANCE: ₹1056
# DEEDEV: ₹300.7
# DEEPAKFERT: ₹1538
# DEEPAKNTR: ₹1901
# Batch saved.
# Processing batch 400 to 500
# DEEPINDS: ₹449
# DELHIVERY: ₹427
# DELTACORP: ₹88.22
# DELTAMAGNT: ₹91
# DEN: ₹37.1
# DENORA: ₹916.25
# DENTA: ₹332
# DEVIT: ₹114.74
# DEVYANI: ₹171.85
# DGCONTENT: ₹44.85
# DHAMPURSUG: ₹145
# DHANBANK: ₹27.86
# DHANI: ₹62.2
# DHANUKA: ₹1734
# DHUNINV: ₹1503.9
# DIACABS: ₹163.05
# DIAMINESQ: ₹382
# DIAMONDYD: ₹991
# DICIND: ₹637
# DIFFNKG: ₹336.8
# DIGIDRIVE: ₹30.34
# DIGISPICE: ₹21.5
# DIVGIITTS: ₹645
# DIVISLAB: ₹6628
# DIXON: ₹16700
# DJML: ₹113.01
# DLF: ₹824.1
# DLINKINDIA: ₹502.85
# DMART: ₹4000
# DMCC: ₹311
# DNAMEDIA: ₹4.78
# DODLA: ₹1303.9
# DOLATALGO: ₹92.11
# DOLLAR: ₹378.3
# DOMS: ₹2388.1
# DONEAR: ₹103
# DPABHUSHAN: ₹1675.5
# DPSCLTD: ₹12.89
# DPWIRES: ₹223
# DRCSYSTEMS: ₹18.59
# DREAMFOLKS: ₹146.95
# DREDGECORP: ₹696.5
# DRREDDY: ₹1277
# DSSL: ₹1027.3
# DTIL: ₹191
# DUCON: ₹5.93
# DVL: ₹364.9
# DWARKESH: ₹45.24
# DYCL: ₹409.9
# DYNAMATECH: ₹7006
# DYNPRO: ₹349.5
# E2E: ₹2139.6
# EASEMYTRIP: ₹10.35
# ECLERX: ₹3654
# ECOSMOBLTY: ₹324
# EDELWEISS: ₹107.68
# EICHERMOT: ₹5425
# EIDPARRY: ₹1169
# EIEL: ₹264.99
# EIFFL: ₹246.5
# EIHAHOTELS: ₹386.55
# EIHOTEL: ₹375.3
# EIMCOELECO: ₹2321.2
# EKC: ₹129
# ELDEHSG: ₹772
# ELECON: ₹580.5
# ELECTCAST: ₹115
# ELGIEQUIP: ₹571.05
# EMAMILTD: ₹575.35
# EMAMIPAP: ₹97.2
# EMBDL: ₹112.35
# EMCURE: ₹1406.1
# EMIL: ₹131.99
# EMMBI: ₹112.6
# EMSLIMITED: ₹622.5
# EMUDHRA: ₹824.5
# ENDURANCE: ₹2575
# ENERGYDEV: ₹20.42
# ENGINERSIN: ₹230
# ENIL: ₹149.5
# ENTERO: ₹1220.9
# EPACK: ₹354
# EPIGRAL: ₹1850
# EPL: ₹227.6
# EQUITASBNK: ₹61.4
# ERIS: ₹1808
# ESABINDIA: ₹5430
# ESAFSFB: ₹31.91
# ESCORTS: ₹3410
# ESSENTIA: ₹2.07
# ESTER: ₹120.01
# ETERNAL: ₹310.5
# ETHOSLTD: ₹2864
# EUREKAFORB: ₹557.05
# EUROTEXIND: ₹14.4
# EVEREADY: ₹430
# EXCEL: ₹1.12
# EXCELINDUS: ₹1350
# EXICOM: ₹163.85
# EXIDEIND: ₹379
# Batch saved.
# Processing batch 500 to 600
# EXPLEOSOL: ₹1239
# EXXARO: ₹8.45
# FACT: ₹956.7
# FAIRCHEMOR: ₹920
# FAZE3Q: ₹688.8
# FCL: ₹269.2
# FCSSOFT: ₹2.62
# FDC: ₹494
# FEDERALBNK: ₹207.78
# FEDFINA: ₹126.5
# FIBERWEB: ₹49.4
# FIEMIND: ₹1982.6
# FILATEX: ₹59.3
# FINCABLES: ₹898
# FINEORG: ₹5200
# FINOPB: ₹272.95
# FINPIPE: ₹208.1
# FIRSTCRY: ₹357.05
# FIVESTAR: ₹689
# FLAIR: ₹317
# FLUOROCHEM: ₹3513
# FMGOETZE: ₹595
# FOCUS: ₹98.89
# FOODSIN: ₹108.5
# FORCEMOT: ₹17840
# FORTIS: ₹844.95
# FOSECOIND: ₹4882.5
# FSL: ₹338
# FUSION: ₹171
# GABRIEL: ₹992.65
# GAEL: ₹105.8
# GAIL: ₹183.63
# GALAPREC: ₹855.1
# GALAXYSURF: ₹2592
# GALLANTT: ₹636
# GANDHAR: ₹168
# GANDHITUBE: ₹745.1
# GANECOS: ₹1465.2
# GANESHBE: ₹96.4
# GANESHHOUC: ₹895
# GANGAFORGE: ₹3.8
# GANGESSECU: ₹160.98
# GARFIBRES: ₹897.95
# GARUDA: ₹169.99
# GATECH: ₹0.63
# GATECHDVR: ₹0.57
# GATEWAY: ₹64.36
# GEECEE: ₹370.55
# GEEKAYWIRE: ₹69.4
# GENCON: ₹40.5
# GENESYS: ₹605
# GENUSPAPER: ₹18.85
# GENUSPOWER: ₹358.3
# GEOJITFSL: ₹74.45
# GEPIL: ₹283.45
# GESHIP: ₹952.5
# GFLLIMITED: ₹63.5
# GHCL: ₹604
# GHCLTEXTIL: ₹91.8
# GICHSGFIN: ₹187.35
# GICRE: ₹373.4
# GILLANDERS: ₹131.05
# GILLETTE: ₹10675
# GIPCL: ₹198.97
# GLAND: ₹2017.8
# GLAXO: ₹3152
# GLENMARK: ₹2141.6
# GLOBAL: ₹67.45
# GLOBALVECT: ₹219.05
# GLOBUSSPR: ₹1239.95
# GLOSTERLTD: ₹650
# GMBREW: ₹714
# GMDCLTD: ₹433.7
# GMMPFAUDLR: ₹1315
# GMRAIRPORT: ₹89.76
# GMRP&UI: ₹112.51
# GNA: ₹311.95
# GNFC: ₹538
# GOACARBON: ₹477.9
# GOCLCORP: ₹374.85
# GOCOLORS: ₹858
# GODAVARIB: ₹318.45
# GODFRYPHLP: ₹8777.5
# GODHA: ₹0.61
# GODIGIT: ₹346.25
# GODREJAGRO: ₹839.8
# GODREJCP: ₹1216.7
# GODREJIND: ₹1135
# GODREJPROP: ₹2230
# GOKEX: ₹900.55
# GOKUL: ₹44.94
# GOKULAGRO: ₹311.8
# GOLDIAM: ₹346.9
# GOLDTECH: ₹69.15
# GOODLUCK: ₹1042.5
# GOPAL: ₹340.1
# GOYALALUM: ₹7.78
# GPIL: ₹188.1
# GPPL: ₹161.3
# GPTHEALTH: ₹162.5
# Batch saved.
# Processing batch 600 to 700
# GPTINFRA: ₹128.2
# GRANULES: ₹469.55
# GRAPHITE: ₹539.75
# GRASIM: ₹2701
# GRAVITA: ₹1870
# GREAVESCOT: ₹200.1
# GREENLAM: ₹247
# GREENPANEL: ₹321.3
# GREENPLY: ₹332
# GREENPOWER: ₹14.06
# GRINDWELL: ₹1635
# GRINFRA: ₹1249
# GRMOVER: ₹378
# GROBTEA: ₹1095
# GRPLTD: ₹2430
# GRSE: ₹2586.5
# GRWRHITECH: ₹3662.2
# GSFC: ₹201.23
# GSLSU: ₹115.48
# GSPL: ₹322.5
# GSS: ₹31.25
# GTECJAINX: ₹0
# GTL: ₹9.7
# GTLINFRA: ₹1.61
# GTPL: ₹120.01
# GUFICBIO: ₹388.5
# GUJALKALI: ₹590.55
# GUJAPOLLO: ₹465
# GUJGASLTD: ₹461
# GUJTHEM: ₹363
# GULFOILLUB: ₹1225.2
# GULFPETRO: ₹43.15
# GULPOLY: ₹170.54
# GVPTECH: ₹10.2
# GVT&D: ₹2454.8
# HAL: ₹4554.9
# HAPPSTMNDS: ₹614
# HAPPYFORGE: ₹971
# HARIOMPIPE: ₹457
# HARRMALAYA: ₹213
# HARSHA: ₹410.7
# HATHWAY: ₹15.16
# HATSUN: ₹922
# HAVELLS: ₹1526.6
# HAVISHA: ₹2.14
# HBLENGINE: ₹570.5
# HBSL: ₹85.2
# HCC: ₹26.89
# HCG: ₹570
# HCLTECH: ₹1490
# HDFCAMC: ₹5526.5
# HDFCBANK: ₹2005
# HDFCLIFE: ₹760.1
# HECPROJECT: ₹0
# HEG: ₹513.35
# HEIDELBERG: ₹212.51
# HEMIPROP: ₹131.49
# HERCULES: ₹184.45
# HERITGFOOD: ₹460.2
# HEROMOTOCO: ₹4221.4
# HESTERBIO: ₹1800
# HEUBACHIND: ₹590.1
# HEXATRADEX: ₹183.51
# HEXT: ₹737.2
# HFCL: ₹75.9
# HGINFRA: ₹1066
# HGS: ₹578
# HIKAL: ₹332.15
# HIMATSEIDE: ₹154.7
# HINDALCO: ₹694.1
# HINDCOMPOS: ₹485.1
# HINDCON: ₹34.92
# HINDCOPPER: ₹256.65
# HINDMOTORS: ₹23.85
# HINDOILEXP: ₹162
# HINDPETRO: ₹422.85
# HINDUNILVR: ₹2417
# HINDWAREAP: ₹255.7
# HINDZINC: ₹438.05
# HIRECT: ₹1350.6
# HISARMETAL: ₹201.5
# HITECH: ₹92.6
# HITECHCORP: ₹196
# HLEGLAS: ₹430
# HLVLTD: ₹12.71
# HMAAGRO: ₹30.45
# HMVL: ₹87.68
# HNDFDS: ₹548
# HOMEFIRST: ₹1439.9
# HONASA: ₹264
# HONAUT: ₹39705
# HONDAPOWER: ₹2840
# HOVS: ₹58.49
# HPAL: ₹49
# HPIL: ₹143.58
# HPL: ₹556.3
# HSCL: ₹496
# HUBTOWN: ₹320
# HUDCO: ₹218.1
# HUHTAMAKI: ₹219.1
# Batch saved.
# Processing batch 700 to 800
# HYBRIDFIN: ₹0
# HYUNDAI: ₹2090.9
# ICEMAKE: ₹784.85
# ICICIBANK: ₹1477.9
# ICICIGI: ₹1916
# ICICIPRULI: ₹618.2
# ICIL: ₹289.9
# ICRA: ₹6655
# IDBI: ₹93.3
# IDEA: ₹7.22
# IDEAFORGE: ₹474
# IDFCFIRSTB: ₹70.63
# IEL: ₹17.41
# IEX: ₹144.8
# IFBIND: ₹1385
# IFCI: ₹58.6
# IFGLEXPOR: ₹245.05
# IGARASHI: ₹612
# IGIL: ₹405.8
# IGL: ₹201.6
# IGPL: ₹489
# IIFL: ₹517
# IIFLCAPS: ₹306.9
# IITL: ₹166.1
# IKIO: ₹207.53
# IKS: ₹1590.2
# IMAGICAA: ₹65
# IMFA: ₹749
# IMPAL: ₹1081.1
# INCREDIBLE: ₹40.99
# INDBANK: ₹33.57
# INDGN: ₹558.05
# INDHOTEL: ₹746.5
# INDIACEM: ₹357.75
# INDIAGLYCO: ₹1733
# INDIAMART: ₹2569.1
# INDIANB: ₹636.7
# INDIANCARD: ₹307.3
# INDIANHUME: ₹423.95
# INDIASHLTR: ₹933
# INDIGO: ₹5785
# INDIGOPNTS: ₹1142
# INDNIPPON: ₹773.5
# INDOAMIN attempt 1 failed: HTTPSConnectionPool(host='www.nseindia.com', port=443): Read timed out. (read timeout=10)
# INDOAMIN: ₹150.7
# INDOBORAX: ₹288.55
# INDOCO: ₹319
# INDORAMA: ₹50.51
# INDOSTAR: ₹293
# INDOTECH: ₹1845
# INDOUS: ₹164
# INDOWIND: ₹18.27
# INDRAMEDCO: ₹458
# INDSWFTLAB: ₹105.83
# INDSWFTLTD: ₹16.76
# INDTERRAIN: ₹40.62
# INDUSINDBK: ₹825.5
# INDUSTOWER: ₹392.6
# INFIBEAM: ₹16.06
# INFOBEAN: ₹558
# INFOMEDIA: ₹0
# INFY: ₹1518.5
# INGERRAND: ₹3979
# INNOVACAP: ₹900.35
# INNOVANA: ₹543
# INOXGREEN: ₹171.5
# INOXINDIA: ₹1203
# INOXWIND: ₹157.52
# INSECTICID: ₹1048
# INSPIRISYS: ₹105
# INTELLECT: ₹1039.4
# INTENTECH: ₹83.6
# INTERARCH: ₹2310
# INTLCONV: ₹90.55
# INVENTURE: ₹1.62
# IOB: ₹38.22
# IOC: ₹147.05
# IOLCP: ₹93.8
# IONEXCHANG: ₹469.2
# IPCALAB: ₹1511
# IPL: ₹211.67
# IRB: ₹46.44
# IRCON: ₹181.4
# IRCTC: ₹746.4
# IREDA: ₹153.15
# IRFC: ₹131.13
# IRISDOREME: ₹30.7
# IRMENERGY: ₹291.3
# ISFT: ₹103
# ISGEC: ₹1136.5
# ISHANCH: ₹60
# ITC: ₹409.6
# ITCHOTELS: ₹240
# ITDC: ₹583.65
# ITDCEM: ₹766.2
# ITI: ₹302.5
# IVC: ₹8.87
# IVP: ₹192
# IWEL: ₹0
# IXIGO: ₹218.5
# J&KBANK: ₹109.1
# Batch saved.
# Processing batch 800 to 900
# JAGRAN: ₹71.7
# JAGSNPHARM: ₹267
# JAIBALAJI: ₹114
# JAICORPLTD: ₹103.95
# JAIPURKURT: ₹42.5
# JAMNAAUTO: ₹93.48
# JASH: ₹573.8
# JAYAGROGN: ₹261
# JAYBARMARU: ₹72.6
# JAYNECOIND: ₹42.36
# JAYSREETEA: ₹108.6
# JBCHEPHARM: ₹1705
# JBMA: ₹660.4
# JCHAC: ₹1740
# JETFREIGHT: ₹14.02
# JGCHEM: ₹476.7
# JINDALPOLY: ₹594
# JINDALSAW: ₹222.97
# JINDALSTEL: ₹999.05
# JINDRILL: ₹625
# JINDWORLD: ₹40.4
# JIOFIN: ₹311.1
# JISLDVREQS: ₹30.11
# JISLJALEQS: ₹52.28
# JKCEMENT: ₹6465
# JKIL: ₹729.95
# JKLAKSHMI: ₹938
# JKPAPER: ₹374
# JKTYRE: ₹345.3
# JLHL: ₹1452.3
# JMA: ₹91
# JMFINANCIL: ₹168.8
# JNKINDIA: ₹329
# JOCIL: ₹161.55
# JPOLYINVST: ₹803
# JPPOWER: ₹20.05
# JSFB: ₹452
# JSL: ₹656
# JSWENERGY: ₹513
# JSWINFRA: ₹314.15
# JSWSTEEL: ₹1026.9
# JTEKTINDIA: ₹132.6
# JTLIND: ₹76.9
# JUBLCPL: ₹2170
# JUBLFOOD: ₹649.95
# JUBLINGREA: ₹783
# JUBLPHARMA: ₹1175.9
# JUNIPER: ₹312.1
# JUSTDIAL: ₹849
# JWL: ₹353.85
# JYOTHYLAB: ₹340.75
# JYOTICNC: ₹1036.8
# JYOTISTRUC: ₹16.99
# KAJARIACER: ₹1167
# KAKATCEM: ₹163
# KALAMANDIR: ₹181.8
# KALYANKJIL: ₹593
# KAMATHOTEL: ₹245.9
# KAMDHENU: ₹29.7
# KANORICHEM: ₹88.99
# KANSAINER: ₹245
# KAPSTON: ₹239.01
# KARMAENG: ₹64.9
# KARURVYSYA: ₹260.6
# KAUSHALYA: ₹868.3
# KAYNES: ₹5675
# Please use nse_fno() function to reduce latency.
# KBCGLOBAL attempt 1 failed: 'priceInfo'
# Please use nse_fno() function to reduce latency.
# KBCGLOBAL attempt 2 failed: 'priceInfo'
# Please use nse_fno() function to reduce latency.
# KBCGLOBAL attempt 3 failed: 'priceInfo'
# KBCGLOBAL: ₹None
# KCP: ₹212
# KCPSUGIND: ₹34.8
# KDDL: ₹2861
# KEC: ₹859
# KECL: ₹131.71
# KEEPLEARN: ₹3.16
# KEI: ₹3869.7
# KELLTONTEC: ₹32.49
# KERNEX: ₹1050
# KFINTECH: ₹1162
# KHANDSE: ₹25.31
# KICL: ₹4987
# KIMS: ₹765.05
# KINGFA: ₹3600
# KIOCL: ₹337.5
# KIRIINDUS: ₹565
# KIRLOSBROS: ₹1979
# KIRLOSENG: ₹912.95
# KIRLOSIND: ₹4242
# KIRLPNU: ₹1294.4
# KKCL: ₹549
# KMEW: ₹1715
# KMSUGAR: ₹27.13
# KNRCON: ₹216.5
# KOHINOOR: ₹34.68
# KOKUYOCMLN: ₹113
# KOLTEPATIL: ₹443.2
# KOPRAN: ₹173.8
# KOTAKBANK: ₹2121.2
# KOTARISUG: ₹36.4
# KOTHARIPET: ₹169.69
# KOTHARIPRO: ₹83.58
# KPEL: ₹518.05
# Batch saved.
# Processing batch 900 to 1000
# KPIGREEN: ₹518.5
# KPIL: ₹1150
# KPITTECH: ₹1230
# KPRMILL: ₹1184
# KRBL: ₹390
# KREBSBIO: ₹79.78
# KRISHANA: ₹525.8
# KRITI: ₹0
# KRITIKA: ₹9.33
# KRITINUT: ₹109.52
# KRN: ₹840.1
# KRONOX: ₹184.65
# KROSS: ₹185.25
# KRSNAA: ₹846.5
# KSB: ₹848.45
# KSCL: ₹1121
# KSHITIJPOL: ₹3.17
# KSL: ₹894
# KSOLVES: ₹334
# KTKBANK: ₹187.89
# KUANTUM: ₹132.21
# LAGNAM: ₹101.55
# LAL: ₹11.5
# LALPATHLAB: ₹3077.7
# LAMBODHARA: ₹134.5
# LANCORHOL: ₹21.49
# LANDMARK: ₹497.25
# LAOPALA: ₹278
# LASA: ₹0
# LATENTVIEW: ₹412.5
# LAURUSLABS: ₹839.9
# LAXMICOT: ₹27.59
# LAXMIDENTL: ₹456
# LEMONTREE: ₹152.8
# LEXUS: ₹0
# LFIC: ₹217.5
# LGBBROSLTD: ₹1292
# LGHL: ₹788
# LIBAS: ₹13.38
# LIBERTSHOE: ₹374
# LICHSGFIN: ₹603.75
# LICI: ₹886.3
# LIKHITHA: ₹273.8
# LINC: ₹137.25
# LINCOLN: ₹541.45
# LINDEINDIA: ₹6455
# LLOYDSENGG: ₹72.98
# LLOYDSENT: ₹79.71
# LLOYDSME: ₹1505
# LMW: ₹15500
# LODHA: ₹1277
# LORDSCHLO: ₹210.15
# LOTUSEYE: ₹73.8
# LOVABLE: ₹95.5
# LPDC: ₹8.25
# LT: ₹3442
# LTF: ₹205.15
# LTFOODS: ₹489.05
# LTIM: ₹5081
# LTTS: ₹4217.7
# LUMAXIND: ₹3810
# LUMAXTECH: ₹1030
# LUPIN: ₹1952
# LUXIND: ₹1406.6
# LXCHEM: ₹205.6
# LYKALABS: ₹109.61
# M&M: ₹3245
# M&MFIN: ₹252.95
# MAANALU: ₹121
# MADHAV: ₹45.5
# MADHUCON: ₹6.95
# MADRASFERT: ₹88.85
# MAGADSUGAR: ₹562.2
# MAGNUM: ₹24.1
# MAHABANK: ₹56.63
# MAHAPEXLTD: ₹106.3
# MAHEPC: ₹145.9
# MAHESHWARI: ₹60.94
# MAHLIFE: ₹365
# MAHLOG: ₹351.95
# MAHSCOOTER: ₹14650
# MAHSEAMLES: ₹705
# MAITHANALL: ₹1132.2
# MALLCOM: ₹1326
# MALUPAPER: ₹40.3
# MAMATA: ₹516
# MANAKALUCO: ₹29.8
# MANAKCOAT: ₹160.9
# MANAKSIA: ₹76.17
# MANALIPETC: ₹72.66
# MANAPPURAM: ₹265.6
# MANBA: ₹137.9
# MANCREDIT: ₹190.5
# MANGALAM: ₹89.6
# MANGCHEFER: ₹315.95
# MANGLMCEM: ₹722.1
# MANINDS: ₹425
# MANINFRA: ₹175.7
# MANKIND: ₹2575
# MANOMAY: ₹164.9
# Batch saved.
# Processing batch 1000 to 1100
# MANORAMA: ₹1587
# MANYAVAR: ₹788.1
# MAPMYINDIA: ₹1835.5
# MARALOVER: ₹72.91
# MARATHON: ₹684
# MARICO: ₹694
# MARINE: ₹191.45
# MARKSANS: ₹227.9
# MARUTI: ₹12385
# MASFIN: ₹321.5
# MASTEK: ₹2470
# MASTERTR: ₹166.7
# MATRIMONY: ₹529.8
# MAWANASUG: ₹96.55
# MAXESTATES: ₹511
# MAXHEALTH: ₹1282
# MAXIND: ₹223.47
# MAYURUNIQ: ₹591.35
# MAZDA: ₹287
# MAZDOCK: ₹2894
# MBAPL: ₹425.3
# MBLINFRA: ₹42.05
# MCL: ₹49.6
# MCLEODRUSS: ₹39.8
# MCLOUD: ₹84.5
# MCX: ₹8011
# MEDANTA: ₹1324.3
# MEDIASSIST: ₹530.1
# MEDICAMEQ: ₹388
# MEDICO: ₹40.49
# MEDPLUS: ₹904.05
# MEGASTAR: ₹261.45
# MENONBE: ₹130.49
# METROBRAND: ₹1216
# METROPOLIS: ₹1956
# MFSL: ₹1531.6
# MGEL: ₹16.8
# MGL: ₹1376
# MHLXMIRU: ₹216.12
# MHRIL: ₹359.75
# MICEL: ₹51.83
# MIDHANI: ₹405.8
# MINDACORP: ₹511.15
# MINDTECK: ₹208.5
# MIRZAINT: ₹35.15
# MITCON: ₹78.5
# MITTAL: ₹1.72
# MKPL: ₹7.07
# MMFL: ₹360.25
# MMP: ₹273.9
# MOBIKWIK: ₹257.45
# MODISONLTD: ₹178.9
# MODTHREAD: ₹49.34
# MOHITIND: ₹31
# MOIL: ₹375
# MOKSH: ₹13.89
# MOL: ₹94.49
# MOLDTECH: ₹150
# MOLDTKPAC: ₹731
# MONARCH: ₹365.5
# MONTECARLO: ₹595
# MOREPENLAB: ₹59.6
# MOSCHIP: ₹167.35
# MOTHERSON: ₹100.41
# MOTILALOFS: ₹907
# MOTISONS: ₹21.44
# MOTOGENFIN: ₹26.2
# MPHASIS: ₹2631.1
# MPSLTD: ₹2410
# MRF: ₹148755
# MRPL: ₹140.65
# MSPL: ₹31.66
# MSTCLTD: ₹502.3
# MSUMI: ₹40.85
# MTARTECH: ₹1509
# MTNL: ₹47.35
# MUFIN: ₹88.5
# MUFTI: ₹163
# MUKANDLTD: ₹139.7
# MUKKA: ₹29.19
# MUKTAARTS: ₹83.61
# MUNJALAU: ₹76.98
# MUNJALSHOW: ₹149.9
# MURUDCERA: ₹43.65
# MUTHOOTCAP: ₹329.85
# MUTHOOTFIN: ₹2657
# MUTHOOTMF: ₹168.9
# MVGJL: ₹217.69
# NAGREEKCAP: ₹25.78
# NAGREEKEXP: ₹26.14
# NAHARCAP: ₹306.8
# NAHARINDUS: ₹125.01
# NAHARSPING: ₹257.85
# NAM-INDIA: ₹813.5
# NARMADA: ₹22.39
# NATCAPSUQ: ₹216.55
# NATCOPHARM: ₹970.95
# NATHBIOGEN: ₹187.37
# NATIONALUM: ₹193.6
# NAUKRI: ₹1439
# Batch saved.
# Processing batch 1100 to 1200
# NAVA: ₹612.2
# NAVINFLUOR: ₹5017
# NAVKARCORP: ₹123.21
# NAVKARURB: ₹0
# NAVNETEDUL: ₹150
# NAZARA: ₹1384.2
# NBCC: ₹109.16
# NBIFIN: ₹2890
# NCC: ₹217.7
# NCLIND: ₹223.4
# NDGL: ₹4210
# NDL: ₹3.72
# NDRAUTO: ₹1020.1
# NDTV: ₹146.8
# NECCLTD: ₹22.2
# NECLIFE: ₹17.05
# NELCAST: ₹158
# NELCO: ₹850
# NEOGEN: ₹1569
# NESCO: ₹1240.1
# NESTLEIND: ₹2277
# NETWEB: ₹1932
# NETWORK18: ₹57.51
# NEULANDLAB: ₹13850
# NEWGEN: ₹854.8
# NFL: ₹98.8
# NGIL: ₹29.67
# NH: ₹1990
# NHPC: ₹83.65
# NIACL: ₹178.85
# NIBE: ₹1659.9
# NIITLTD: ₹120.65
# NIITMTS: ₹331
# NILAINFRA: ₹11.4
# NILASPACES: ₹14
# NILKAMAL: ₹1800
# NINSYS: ₹432.85
# NIPPOBATRY: ₹475
# NIRAJ: ₹51.15
# NIRAJISPAT: ₹0
# NITCO: ₹133.3
# NITINSPIN: ₹382.4
# NIVABUPA: ₹83.7
# NKIND: ₹64.2
# NLCINDIA: ₹237.5
# NMDC: ₹71.3
# NOCIL: ₹184.98
# NORTHARC: ₹251.19
# NOVAAGRI: ₹57.64
# NPST: ₹1851.2
# NRAIL: ₹0
# NRBBEARING: ₹290.55
# NRL: ₹75.5
# NSIL: ₹6885
# NSLNISP: ₹38.33
# NTPC: ₹333.65
# NTPCGREEN: ₹105.61
# NUCLEUS: ₹1047.9
# NUVAMA: ₹7345
# NUVOCO: ₹411.45
# NYKAA: ₹212.49
# OAL: ₹379
# OBCL: ₹55
# OBEROIRLTY: ₹1688.1
# OCCL: ₹0
# OCCLLTD: ₹136.57
# OFSS: ₹8598
# OIL: ₹434.9
# OILCOUNTUB: ₹89.9
# OLAELEC: ₹41.16
# OLECTRA: ₹1483
# OMAXAUTO: ₹122.37
# OMAXE: ₹94
# OMINFRAL: ₹122.5
# ONELIFECAP: ₹14.1
# ONEPOINT: ₹49.3
# ONESOURCE: ₹1961
# ONGC: ₹240.49
# ONMOBILE: ₹52.4
# ONWARDTEC: ₹0
# OPTIEMUS: ₹571.35
# ORBTEXP: ₹247.57
# ORCHPHARMA: ₹710
# ORICONENT: ₹44.88
# ORIENTALTL: ₹10.37
# ORIENTBELL: ₹313.05
# ORIENTCEM: ₹251
# ORIENTCER: ₹43.03
# ORIENTELEC: ₹222.01
# ORIENTHOT: ₹147.54
# ORIENTLTD: ₹89.4
# ORIENTPPR: ₹28.75
# ORIENTTECH: ₹327.1
# ORISSAMINE: ₹4936
# OSIAHYPER: ₹0
# OSWALAGRO: ₹82
# OSWALGREEN: ₹44.46
# PAGEIND: ₹46500
# PAISALO: ₹32.46
# PAKKA: ₹200.75
# Batch saved.
# Processing batch 1200 to 1300
# PALASHSECU: ₹124.9
# PANACEABIO: ₹416.05
# PANAMAPET: ₹346.9
# PARACABLES: ₹58
# PARADEEP: ₹190.45
# PARAGMILK: ₹251.5
# PARAS: ₹780.8
# PARASPETRO: ₹2.53
# PARKHOTELS: ₹154.31
# PARSVNATH: ₹18.82
# PATANJALI: ₹1873
# PATELENG: ₹39.15
# PATINTLOG: ₹17.25
# PAVNAIND: ₹411
# PAYTM: ₹1068.15
# PCBL: ₹387.5
# PCJEWELLER: ₹14.67
# PDSL: ₹367.35
# PEARLPOLY: ₹31.5
# PEL: ₹1278
# PENIND: ₹249.1
# PERSISTENT: ₹5159.5
# PETRONET: ₹302.7
# PFC: ₹415.5
# PFIZER: ₹5357.5
# PFOCUS: ₹147.3
# PFS: ₹41.05
# PGEL: ₹799.9
# PGHH: ₹12980
# PGHL: ₹5791
# PGIL: ₹1518
# PHOENIXLTD: ₹1519
# PIDILITIND: ₹2883.9
# PIIND: ₹4105
# PILANIINVS: ₹5103
# PILITA: ₹14.55
# PIONEEREMB: ₹40.15
# PITTIENG: ₹944.5
# PIXTRANS: ₹1508
# PKTEA: ₹685
# PLASTIBLEN: ₹194.8
# PLATIND: ₹299.9
# PLAZACABLE: ₹59.5
# PNB: ₹108.2
# PNBGILTS: ₹108.3
# PNBHOUSING: ₹1008.7
# PNCINFRA: ₹304
# PNGJL: ₹581.5
# POCL: ₹1098.8
# PODDARMENT: ₹298.5
# POKARNA: ₹1007
# POLICYBZR: ₹1784.7
# POLYCAB: ₹6733
# POLYMED: ₹2058.5
# POLYPLEX: ₹1131.4
# PONNIERODE: ₹299.95
# POONAWALLA: ₹412.45
# POWERGRID: ₹291.85
# POWERINDIA: ₹19350
# POWERMECH: ₹3050
# PPAP: ₹256.76
# PPL: ₹378.5
# PPLPHARMA: ₹202.3
# PRABHA: ₹263.3
# PRAENG: ₹20.2
# PRAJIND: ₹484.55
# PRAKASH: ₹177.2
# PRAKASHSTL: ₹6.01
# PRECAM: ₹186.5
# PRECOT: ₹602
# PRECWIRE: ₹180.2
# PREMEXPLN: ₹481
# PREMIERENE: ₹1084.7
# PREMIERPOL: ₹51.65
# PRESTIGE: ₹1670.6
# PRICOLLTD: ₹439
# PRIMESECU: ₹287.75
# PRIMO: ₹29.9
# PRINCEPIPE: ₹329.1
# PRITI: ₹91
# PRITIKAUTO: ₹18
# PRIVISCL: ₹2454
# PROTEAN: ₹797.7
# PRSMJOHNSN: ₹157.84
# PRUDENT: ₹2916
# PRUDMOULI: ₹43.47
# PSB: ₹29.86
# PSPPROJECT: ₹810
# PTC: ₹191.3
# PTCIL: ₹14530
# PTL: ₹40.05
# PUNJABCHEM: ₹1326.3
# PURVA: ₹273.85
# PVP: ₹21.12
# PVRINOX: ₹1002.5
# PVSL: ₹125
# PYRAMID: ₹166.02
# QPOWER: ₹788
# QUADFUTURE: ₹469.3
# QUESS: ₹301
# Batch saved.
# Processing batch 1300 to 1400
# QUICKHEAL: ₹320.8
# RACE: ₹238.45
# RACLGEAR: ₹1007.8
# RADAAN: ₹4.01
# RADHIKAJWE: ₹100
# RADIANTCMS: ₹57.2
# RADICO: ₹2700
# RADIOCITY: ₹8.95
# RAILTEL: ₹391.8
# RAIN: ₹155.3
# RAINBOW: ₹1556.5
# RAJESHEXPO: ₹194.81
# RAJOOENG: ₹114.48
# RAJRATAN: ₹403.5
# RAJSREESUG: ₹46.05
# RALLIS: ₹357.5
# RAMASTEEL: ₹11.24
# RAMCOCEM: ₹1148.2
# RAMCOIND: ₹286.2
# RAMCOSYS: ₹397.5
# RAMKY: ₹580.35
# RAMRAT: ₹703
# RANASUG: ₹14.84
# RANEHOLDIN: ₹1572.3
# RATEGAIN: ₹443.15
# RATNAMANI: ₹2705.9
# RATNAVEER: ₹155.49
# RAYMOND: ₹699.95
# RAYMONDLSL: ₹1094.4
# RBA: ₹81.8
# RBLBANK: ₹253.75
# RCF: ₹152.1
# RECLTD: ₹400.3
# REDINGTON: ₹294.55
# REDTAPE: ₹132.99
# REFEX: ₹406
# REGENCERAM: ₹52.47
# RELAXO: ₹487.35
# RELCHEMQ: ₹187
# RELIABLE: ₹72.6
# RELIANCE: ₹1392.4
# RELIGARE: ₹274.1
# RELTD: ₹140.6
# REMSONSIND: ₹131.6
# RENUKA: ₹30.9
# REPCOHOME: ₹426.5
# REPL: ₹175.5
# REPRO: ₹550
# RESPONIND: ₹225
# RETAIL: ₹37.79
# RGL: ₹115.3
# RHIM: ₹492.9
# RHL: ₹293
# RICOAUTO: ₹71.39
# RIIL: ₹904.1
# RISHABH: ₹287.5
# RITCO: ₹289.4
# RITES: ₹264.7
# RKDL: ₹29.15
# RKEC: ₹66.07
# RKFORGE: ₹622
# RKSWAMY: ₹164.7
# RML: ₹854.9
# ROHLTD: ₹425
# ROLEXRINGS: ₹1470
# ROML: ₹52
# ROSSARI: ₹714.5
# ROTO: ₹90.05
# ROUTE: ₹925.9
# RPEL: ₹659
# RPGLIFE: ₹2499
# RPOWER: ₹56.78
# RPPL: ₹25.53
# RPSGVENT: ₹993
# RPTECH: ₹294
# RRKABEL: ₹1366.5
# RSWM: ₹162.5
# RSYSTEMS: ₹419
# RTNINDIA: ₹56.9
# RTNPOWER: ₹13.43
# RUBFILA: ₹84.58
# RUBYMILLS: ₹236.5
# RUCHINFRA: ₹7.52
# RUCHIRA: ₹135.45
# RUPA: ₹213.05
# RUSHIL: ₹26
# RUSTOMJEE: ₹625
# RVHL: ₹45
# RVNL: ₹365.3
# SADBHIN: ₹4.47
# SAFARI: ₹2110
# SAGARDEEP: ₹28.35
# SAGCEM: ₹239.86
# SAGILITY: ₹43.85
# SAHYADRI: ₹316
# SAIL: ₹130.4
# SAILIFE: ₹837
# SAKAR: ₹363
# SAKHTISUG: ₹24.46
# SAKSOFT: ₹216.98
# Batch saved.
# Processing batch 1400 to 1500
# SALASAR: ₹7.27
# SALONA: ₹252.1
# SALSTEEL: ₹15.91
# SALZERELEC: ₹812
# SAMHI: ₹235
# SAMMAANCAP: ₹126.38
# SAMPANN: ₹32.4
# SANATHAN: ₹525
# SANDESH: ₹1161
# SANDHAR: ₹495.45
# SANDUMA: ₹457.95
# SANGAMIND: ₹450
# SANGHIIND: ₹68
# SANGHVIMOV: ₹263
# SANOFI: ₹5846
# SANOFICONR: ₹5000
# SANSERA: ₹1370
# SANSTAR: ₹90.75
# SAPPHIRE: ₹333.9
# SARDAEN: ₹434.1
# SAREGAMA: ₹483
# SARVESHWAR: ₹7.98
# SASKEN: ₹1460
# SASTASUNDR: ₹299
# SATIA: ₹85.91
# SATIN: ₹150
# Please use nse_fno() function to reduce latency.
# SATINDLTD attempt 1 failed: 'priceInfo'
# Please use nse_fno() function to reduce latency.
# SATINDLTD attempt 2 failed: 'priceInfo'
# Please use nse_fno() function to reduce latency.
# SATINDLTD attempt 3 failed: 'priceInfo'
# SATINDLTD: ₹None
# SAURASHCEM: ₹103.55
# SBC: ₹17.38
# SBCL: ₹552.8
# SBFC: ₹109.43
# SBICARD: ₹891.1
# SBILIFE: ₹1830.7
# SBIN: ₹805.9
# SCHAEFFLER: ₹4034.9
# SCHAND: ₹221.21
# SCHNEIDER: ₹905.55
# SCI: ₹218.63
# SCILAL: ₹51.2
# SCPL: ₹295.05
# SDBL: ₹157
# SEAMECLTD: ₹832
# SELAN: ₹609
# SENCO: ₹340
# SENORES: ₹670
# SEPC: ₹11.68
# SEQUENT: ₹175.45
# SERVOTECH: ₹138.05
# SESHAPAPER: ₹280.65
# SFL: ₹660.95
# SGIL: ₹550
# SGL: ₹14.75
# SGLTL: ₹174.65
# SHAH: ₹3.84
# SHAILY: ₹1591
# SHAKTIPUMP: ₹898
# SHALBY: ₹206.15
# SHALPAINTS: ₹84.62
# SHANKARA: ₹1007.5
# SHANTIGEAR: ₹584
# SHARDACROP: ₹1090.5
# SHARDAMOTR: ₹1066
# SHAREINDIA: ₹171.7
# SHILPAMED: ₹911
# SHIVALIK: ₹545
# SHIVAMAUTO: ₹30.5
# SHIVAMILLS: ₹76.2
# SHIVATEX: ₹200.09
# SHK: ₹262
# SHOPERSTOP: ₹529.15
# SHRADHA: ₹67.8
# SHREDIGCEM: ₹85.3
# SHREECEM: ₹30955
# SHREEPUSHK: ₹365.7
# SHREERAMA: ₹41.25
# SHREYANIND: ₹237.99
# SHRIPISTON: ₹2414.8
# SHRIRAMFIN: ₹610.5
# SHRIRAMPPS: ₹95.4
# SHYAMMETL: ₹969.1
# SHYAMTEL: ₹15.18
# SIEMENS: ₹3035.4
# SIGACHI: ₹38.71
# SIGNATURE: ₹1180
# SIGNPOST: ₹236.5
# SIKKO: ₹74
# SIL: ₹19.75
# SILINV: ₹580.5
# SILLYMONKS: ₹18
# SILVERTUC: ₹786.05
# SIMPLEXINF: ₹305.95
# SINCLAIR: ₹102.1
# SINDHUTRAD: ₹30.75
# SINTERCOM: ₹128
# SIRCA: ₹417.3
# SIS: ₹380
# SIYSIL: ₹694.5
# SJS: ₹1248
# SJVN: ₹95.23
# SKFINDIA: ₹4900
# Batch saved.
# Processing batch 1500 to 1600
# SKIPPER: ₹457.5
# SKMEGGPROD: ₹0
# SMARTLINK: ₹148.95
# SMCGLOBAL: ₹144.9
# SMLISUZU: ₹3784.7
# SMLT: ₹117.16
# SMSLIFE: ₹1167
# SMSPHARMA: ₹237.1
# SNOWMAN: ₹56
# SOBHA: ₹1625
# SOFTTECH: ₹361
# SOLARA: ₹696
# SOLARINDS: ₹14535
# SOMANYCERA: ₹536
# SOMATEX: ₹0
# SOMICONVEY: ₹150.02
# SONACOMS: ₹470
# SONAMLTD: ₹49.37
# SONATSOFTW: ₹412.3
# SOTL: ₹405.8
# SOUTHBANK: ₹29.75
# SOUTHWEST: ₹142.09
# SPAL: ₹837
# SPANDANA: ₹274.05
# SPARC: ₹151.7
# SPECIALITY: ₹132
# SPECTRUM: ₹1579.7
# SPENCERS: ₹60.85
# SPIC: ₹98.19
# SPLPETRO: ₹792.65
# SPMLINFRA: ₹269.79
# SPORTKING: ₹128.9
# SRD: ₹81.9
# SREEL: ₹238.1
# SRF: ₹3044.9
# SRGHFL: ₹314
# SRHHYPOLTD: ₹642.8
# SRM: ₹465.2
# SSDL: ₹96.33
# SSWL: ₹240.65
# STANLEY: ₹336
# STAR: ₹905
# STARCEMENT: ₹231.3
# STARHEALTH: ₹426.9
# STARPAPER: ₹177.5
# STARTECK: ₹305.25
# STCINDIA: ₹128.17
# STEELCAS: ₹1175
# STEELCITY: ₹108.7
# STEELXIND: ₹10.7
# STERTOOLS: ₹358
# STLTECH: ₹116.8
# STOVEKRAFT: ₹574.9
# STYLAMIND: ₹1881.2
# STYLEBAAZA: ₹268.55
# STYRENIX: ₹3059.9
# SUBEXLTD: ₹13.66
# SUBROS: ₹840.95
# SUDARSCHEM: ₹1250
# SUKHJITS: ₹175.5
# SULA: ₹292.4
# SUMICHEM: ₹585.95
# SUMIT: ₹90
# SUMMITSEC: ₹2072
# SUNCLAY: ₹1950
# SUNDARAM: ₹2.14
# SUNDARMFIN: ₹4963
# SUNDARMHLD: ₹485.9
# SUNDRMBRAK: ₹899.95
# SUNDRMFAST: ₹1000
# SUNDROP: ₹871.3
# SUNFLAG: ₹282.15
# SUNPHARMA: ₹1702
# SUNTECK: ₹419.85
# SUNTV: ₹575.1
# SUPERHOUSE: ₹174
# SUPERSPIN: ₹10.04
# SUPRAJIT: ₹468
# SUPREME: ₹76.44
# SUPREMEIND: ₹4315
# SUPRIYA: ₹682.3
# SURAJEST: ₹316
# SURAJLTD: ₹355.05
# SURAKSHA: ₹308
# SURANASOL: ₹33.14
# SURANAT&P: ₹19.04
# SURYALAXMI: ₹71.61
# SURYAROSNI: ₹336.15
# SURYODAY: ₹132.05
# SUVEN: ₹283
# SUZLON: ₹63.74
# SWANENERGY: ₹473.25
# SWARAJENG: ₹4222
# SWIGGY: ₹408.3
# SWSOLAR: ₹289
# SYMPHONY: ₹1115
# SYNCOMF: ₹18.1
# SYNGENE: ₹679.45
# SYRMA: ₹727
# TAINWALCHM: ₹243.55
# Batch saved.
# Processing batch 1600 to 1700
# TAJGVK: ₹412.35
# TALBROAUTO: ₹282
# TANLA: ₹649.9
# TARC: ₹186.99
# TARIL: ₹491.95
# TARMAT: ₹55.28
# TARSONS: ₹371.1
# TASTYBITE: ₹10775
# TATACHEM: ₹946.55
# TATACOMM: ₹1720
# TATACONSUM: ₹1053
# TATAELXSI: ₹6041
# TATAINVEST: ₹6605
# TATAMOTORS: ₹687.55
# TATAPOWER: ₹395
# TATASTEEL: ₹161.51
# TATATECH: ₹707
# TATVA: ₹1135
# TBOTEK: ₹1385.1
# TBZ: ₹189.88
# TCI: ₹1207
# TCIEXP: ₹713.2
# TCIFINANCE: ₹14.15
# TCPLPACK: ₹3633
# TCS: ₹3140
# TDPOWERSYS: ₹468
# TEAMLEASE: ₹1922.5
# TECHM: ₹1460.7
# TECHNOE: ₹1439.9
# TEGA: ₹1876
# TEJASNET: ₹600.95
# TEXINFRA: ₹98.69
# TEXMOPIPES: ₹61.65
# TEXRAIL: ₹152.9
# TFCILTD: ₹290
# TGBHOTELS: ₹12.3
# THANGAMAYL: ₹1848
# THEINVEST: ₹171.55
# THEJO: ₹2319.9
# THELEELA: ₹441.5
# THEMISMED: ₹116.5
# THERMAX: ₹3726.7
# THOMASCOOK attempt 1 failed: HTTPSConnectionPool(host='www.nseindia.com', port=443): Read timed out. (read timeout=10)
# THOMASCOOK: ₹170.3
# THOMASCOTT: ₹335
# THYROCARE: ₹1310.7
# TI: ₹495.35
# TIIL: ₹3300
# TIINDIA: ₹2869
# TIL: ₹349.1
# TIMESGTY: ₹217.5
# TIMETECHNO: ₹449.3
# TIMKEN: ₹3365
# TINNARUBR: ₹923
# TIPSFILMS: ₹527
# TIPSMUSIC: ₹613
# TIRUMALCHM: ₹295.95
# TITAGARH: ₹878
# TITAN: ₹3451.2
# TMB: ₹455.2
# TNPETRO: ₹103.4
# TNPL: ₹166.75
# TNTELE: ₹0
# TOKYOPLAST: ₹116.05
# TORNTPHARM: ₹3605.4
# TORNTPOWER: ₹1328.8
# TOTAL: ₹78.5
# TOUCHWOOD: ₹102.87
# TPLPLASTEH: ₹76.26
# TRACXN: ₹56.02
# TRANSRAILL: ₹692
# TRANSWORLD: ₹269.65
# TREJHARA: ₹218.5
# TREL: ₹34.13
# TRENT: ₹5050
# TRF: ₹362.8
# TRIDENT: ₹31.43
# TRIGYN: ₹81.54
# TRITURBINE: ₹617.25
# TRIVENI: ₹363.8
# TTKHLTCARE: ₹1291
# TTKPRESTIG: ₹630
# TTL: ₹12.95
# TTML: ₹61.57
# TVSELECT: ₹415.95
# TVSHLTD: ₹11887
# TVSMOTOR: ₹2773
# TVSSCS: ₹127.72
# TVSSRICHAK: ₹2992
# TVTODAY: ₹170.37
# UBL: ₹2037.9
# UCAL: ₹150
# UCOBANK: ₹30.42
# UDAICEMENT: ₹34.85
# UDS: ₹281.45
# UFLEX: ₹592
# UFO: ₹71
# UGARSUGAR: ₹45.19
# UGROCAP: ₹169.9
# UJJIVANSFB: ₹43.25
# ULTRACEMCO: ₹12240
# Batch saved.
# Processing batch 1700 to 1800
# UMAEXPORTS: ₹49.31
# UMANGDAIRY: ₹0
# UMIYA-MRO: ₹82
# UNICHEMLAB: ₹630.1
# UNIDT: ₹218.2
# UNIECOM: ₹123.58
# UNIENTER: ₹162.01
# UNIMECH: ₹1150.2
# UNIONBANK: ₹136.25
# UNIPARTS: ₹370
# UNITDSPR: ₹1311
# UNITEDPOLY: ₹25.14
# UNITEDTEA: ₹461.15
# UNIVASTU: ₹267
# UNIVCABLES: ₹746.1
# UNIVPHOTO: ₹267
# UNOMINDA: ₹1087.5
# UPL: ₹723
# URJA: ₹14.46
# USHAMART: ₹366.1
# USK: ₹35.36
# UTIAMC: ₹1359.2
# UTKARSHBNK: ₹22.62
# UTTAMSUGAR: ₹267
# UYFINCORP: ₹18.3
# VADILALIND: ₹5470.5
# VAIBHAVGBL: ₹233.9
# VAISHALI: ₹12.35
# VALIANTORG: ₹384
# VARDHACRLC: ₹50.01
# VARDMNPOLY: ₹10.6
# VARROC: ₹538.2
# VASCONEQ: ₹52.85
# VASWANI: ₹53
# VBL: ₹476.5
# VCL: ₹1.15
# VEDL: ₹443.5
# VEEDOL: ₹1677.9
# VENKEYS: ₹1543
# VENTIVE: ₹760
# VENUSPIPES: ₹1466
# VERANDA: ₹224.5
# VESUVIUS: ₹527
# VETO: ₹125.63
# VGUARD: ₹402
# VHL: ₹4120
# VIDHIING: ₹414
# VIJAYA: ₹1074
# VIJIFIN: ₹3.94
# VIKASECO: ₹2.32
# VIKASLIFE: ₹2.45
# VIMTALABS: ₹593
# VINATIORGA: ₹1863.8
# VINCOFE: ₹146.81
# VINDHYATEL: ₹1608
# VIPIND: ₹450.05
# VIRINCHI: ₹27.61
# VISAKAIND: ₹83.95
# VISHNU: ₹495.25
# VISHWARAJ: ₹9.38
# VIVIDHA: ₹0.82
# VLSFINANCE: ₹236
# VMART: ₹803.25
# VMM: ₹139.45
# VOLTAMP: ₹8840
# VOLTAS: ₹1313.6
# VPRPL: ₹163.5
# VRAJ: ₹169
# VRLLOG: ₹620.65
# VSSL: ₹258
# VSTIND: ₹282
# VSTL: ₹168
# VSTTILLERS: ₹4560
# VTL: ₹475.05
# WAAREEENER: ₹3190.1
# WAAREERTL: ₹1054
# WABAG: ₹1621
# WALCHANNAG: ₹208
# WCIL: ₹109.31
# WEALTH: ₹1190
# WEBELSOLAR: ₹1388.4
# WEIZMANIND: ₹118.59
# WEL: ₹167.45
# WELCORP: ₹884
# WELENT: ₹497.3
# WELSPUNLIV: ₹136.6
# WENDT: ₹9650
# WESTLIFE: ₹756.8
# WHEELS: ₹793.1
# WHIRLPOOL: ₹1409
# WILLAMAGOR: ₹34.9
# WINDLAS: ₹984.05
# WINDMACHIN: ₹340.5
# WIPL: ₹154.3
# WIPRO: ₹259.7
# WOCKPHARMA: ₹1680
# WONDERLA: ₹646.95
# WORTH: ₹161.5
# WSTCSTPAPR: ₹543.8
# XCHANGING: ₹91
# Batch saved.
# Processing batch 1800 to 1822
# XPROINDIA: ₹1180
# XTGLOBAL: ₹34.02
# YASHO: ₹1950.3
# YATHARTH: ₹626.3
# YATRA: ₹94.45
# YESBANK: ₹19.6
# YUKEN: ₹1076.5
# ZAGGLE: ₹384
# ZEEL: ₹123.48
# ZEEMEDIA: ₹13.58
# ZENITHSTL: ₹8.73
# ZENSARTECH: ₹794
# ZENTEC: ₹1773.2
# ZFCVINDIA: ₹13500
# ZIMLAB: ₹113.5
# ZODIAC: ₹457
# ZODIACLOTH: ₹106
# ZOTA: ₹1200.65
# ZUARI: ₹213.5
# ZUARIIND: ₹265.2
# ZYDUSLIFE: ₹973.5
# ZYDUSWELL: ₹2093.4
# Batch saved.
# All 1822 prices saved to live_prices/live_prices_2025-07-27.csv

# %%
import pandas as pd
import os

input_folder = "nse_historical_data"  # folder where your CSV files are
output_folder = "cleaned_stocks"

os.makedirs(output_folder, exist_ok=True)

for file in os.listdir(input_folder):
    if file.endswith(".csv"):
        filepath = os.path.join(input_folder, file)
        try:
            # Skip header lines with redundant stock names
            df = pd.read_csv(filepath, skiprows=2)

            # Case 1: 6 columns (Date, Close, High, Low, Open, Volume)
            if df.shape[1] == 6:
                df.columns = ['DATE', 'CLOSE', 'HIGH', 'LOW', 'OPEN', 'VOLUME']
                df['STOCK'] = file.replace('.csv', '') + '.NS'

            # Case 2: 7 columns (already includes stock name column)
            elif df.shape[1] == 7:
                df.columns = ['DATE', 'CLOSE', 'HIGH', 'LOW', 'OPEN', 'VOLUME', 'STOCK']

            else:
                print(f"Skipping {file}: unexpected number of columns ({df.shape[1]})")
                continue

            # Save cleaned file
            output_path = os.path.join(output_folder, file)
            df.to_csv(output_path, index=False)

        except Exception as e:
            print(f"Error processing {file}: {e}")

# %%
import os
import pandas as pd

# Set your folder path here
folder_path = "cleaned_stocks"  

# Empty list to store latest rows
latest_data = []

# Loop over all files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        file_path = os.path.join(folder_path, filename)
        try:
            # Read the CSV
            df = pd.read_csv(file_path)

            # Check if required columns exist
            if 'DATE' in df.columns:
                # Convert date to datetime
                df['DATE'] = pd.to_datetime(df['DATE'], errors='coerce')

                # Drop rows with invalid dates
                df = df.dropna(subset=['DATE'])

                # Sort and take latest row
                latest_row = df.sort_values('DATE').iloc[-1]

                # Add stock name from filename (remove .csv)
                latest_row['STOCK'] = filename.replace('.csv', '')

                # Append to list
                latest_data.append(latest_row)
        except Exception as e:
            print(f"Error processing {filename}: {e}")

# Combine all latest rows
latest_df = pd.DataFrame(latest_data)

# Save to CSV
latest_df.to_csv("latest_stock_snapshot.csv", index=False)
print("Saved 'latest_stock_snapshot.csv' with latest row from each stock.")
# Out:
# Saved 'latest_stock_snapshot.csv' with latest row from each stock.

# %%
import pandas as pd
import os

all_data = []  # To hold enhanced data for each stock

folder_path = "cleaned_stocks"  # Folder with cleaned .csv files

for file in os.listdir(folder_path):
    if file.endswith(".csv"):
        file_path = os.path.join(folder_path, file)
        stock_name = file.replace('.csv', '')
        try:
            df = pd.read_csv(file_path)
            df['DATE'] = pd.to_datetime(df['DATE'], errors='coerce')
            df = df.dropna(subset=['DATE'])
            df = df.sort_values('DATE')
            
            # Calculate daily return
            df['daily_return'] = df['CLOSE'].pct_change()
            
            # 30-day rolling metrics
            df['volatility_30d'] = df['daily_return'].rolling(30).std()
            df['avg_return_30d'] = df['daily_return'].rolling(30).mean()
            
            # Get latest available record (most recent row)
            latest = df.iloc[-1].copy()
            latest['STOCK'] = stock_name  # Add stock column
            all_data.append(latest)
        except Exception as e:
            print(f"Error processing {file}: {e}")

# Combine all
enhanced_df = pd.DataFrame(all_data)

# Categorize risk based on volatility
def get_risk(vol):
    if pd.isna(vol):
        return 'Unknown'
    if vol < 0.01:
        return 'Low'
    elif vol < 0.02:
        return 'Medium'
    else:
        return 'High'

enhanced_df['risk_level'] = enhanced_df['volatility_30d'].apply(get_risk)

# Save result
enhanced_df.to_csv("enhanced_stock_snapshot.csv", index=False)
print("Saved enhanced_stock_snapshot.csv with proper 30-day calculations.")
# Out:
# Saved enhanced_stock_snapshot.csv with proper 30-day calculations.

# %%
import os
import shutil

# Original file path (in current directory)
src_path = 'enhanced_stock_snapshot.csv'

# Destination folder
dst_folder = 'live_stocks_data_final'
os.makedirs(dst_folder, exist_ok=True)

# Full destination path
dst_path = os.path.join(dst_folder, 'enhanced_stock_snapshot.csv')

# Move file
shutil.move(src_path, dst_path)

print(f"File moved to: {dst_path}")
# Out:
# File moved to: live_stocks_data_final\enhanced_stock_snapshot.csv

# %%
import pandas as pd

# ------------------------------
# Load Enhanced Stock Snapshot
# ------------------------------
df = pd.read_csv("enhanced_stock_snapshot.csv")

# Rename for consistency
df.rename(columns={
    'avg_return_30d': 'avg_return',
    'ISIN': 'stock_id' if 'ISIN' in df.columns else 'STOCK'
}, inplace=True)

# If 'stock_id' doesn't exist, fallback to 'STOCK' column
if 'stock_id' not in df.columns:
    df['stock_id'] = df['STOCK']

# ------------------------------
# Simulated User Data
# ------------------------------
user_data = pd.DataFrame([
    {'user_id': 1, 'age': 28, 'gender': 'Male', 'income': 600000, 'risk_tolerance': 'High'},
    {'user_id': 2, 'age': 45, 'gender': 'Female', 'income': 800000, 'risk_tolerance': 'Medium'},
    {'user_id': 3, 'age': 35, 'gender': 'Male', 'income': 400000, 'risk_tolerance': 'Low'}
])

# ------------------------------
# Risk Level Mapping
# ------------------------------
risk_rank = {'Low': 1, 'Medium': 2, 'High': 3}

# ------------------------------
# Recommendation Logic
# ------------------------------
def recommend_stocks(user, stock_df, top_n=5):
    user_risk_rank = risk_rank[user['risk_tolerance']]

    # Filter stocks that match or are lower than user's risk tolerance
    eligible = stock_df[stock_df['risk_level'].map(risk_rank) <= user_risk_rank]

    # Drop rows with missing avg_return
    eligible = eligible.dropna(subset=['avg_return'])

    # Sort by highest avg return
    top_stocks = eligible.sort_values('avg_return', ascending=False).head(top_n)

    return top_stocks[['stock_id', 'avg_return', 'risk_level']]

# ------------------------------
# Run for Each User
# ------------------------------
for _, user in user_data.iterrows():
    print(f"\nRecommendations for User {user['user_id']} (Risk: {user['risk_tolerance']}):")
    print(recommend_stocks(user, df).to_string(index=False))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 6
#       1 import pandas as pd
#       3 # ------------------------------
#       4 # Load Enhanced Stock Snapshot
#       5 # ------------------------------
# ----> 6 df = pd.read_csv("enhanced_stock_snapshot.csv")
#       8 # Rename for consistency
#       9 df.rename(columns={
#      10     'avg_return_30d': 'avg_return',
#      11     'ISIN': 'stock_id' if 'ISIN' in df.columns else 'STOCK'
#      12 }, inplace=True)
#
# File ~\anaconda3\envs\LATEST\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\envs\LATEST\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\anaconda3\envs\LATEST\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\envs\LATEST\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\anaconda3\envs\LATEST\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'enhanced_stock_snapshot.csv'

# %%
all_recommendations = []

for _, user in user_data.iterrows():
    recs = recommend_stocks(user, df)
    recs['user_id'] = user['user_id']
    all_recommendations.append(recs)

final_df = pd.concat(all_recommendations, ignore_index=True)
final_df.to_csv("user_stock_recommendations.csv", index=False)
print("Saved recommendations to 'user_stock_recommendations.csv'")
